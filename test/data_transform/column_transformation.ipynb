# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/meruozhu/Downloads/MP_data/MP_codes/MP/Data/sudden_drift/BPIC17.csv')

# %%
df.columns
# Out:
# Index(['Action', 'role', 'concept:name', 'EventOrigin', 'eventID',
#        'lifecycle:transition', 'completeTime', 'case:LoanGoal',
#        'case:ApplicationType', 'case', 'case:RequestedAmount',
#        'FirstWithdrawalAmount', 'NumberOfTerms', 'Accepted', 'MonthlyCost',
#        'Selected', 'CreditScore', 'OfferedAmount', 'OfferID', 'event'],
#       dtype='object')

# %%
df['case']=df['case:concept:name']

# %%
df['event']=df['concept:name']

# %%
df['completeTime']=df['time:timestamp']

# %% [markdown]
# ### change complete time format

# %%
df['completeTime']=pd.to_datetime(df['completeTime']).dt.strftime('%Y-%m-%d %H:%M:%S+00:00')

# %%
df
# Out:
#              Action     role            concept:name  EventOrigin  \
# 0           Created   User_1    A_Create Application  Application
# 1       statechange   User_1             A_Submitted  Application
# 2           Created   User_1          W_Handle leads     Workflow
# 3           Deleted   User_1          W_Handle leads     Workflow
# 4           Created   User_1  W_Complete application     Workflow
# ...             ...      ...                     ...          ...
# 199995  statechange  User_87              O_Accepted        Offer
# 199996  statechange  User_87               A_Pending  Application
# 199997      Deleted  User_87  W_Validate application     Workflow
# 199998      Created  User_28    A_Create Application  Application
# 199999      Created  User_28  W_Complete application     Workflow
#
#                        eventID lifecycle:transition  \
# 0        Application_652823628             complete
# 1         ApplState_1582051990             complete
# ...

# %%
df.to_csv('/Users/meruozhu/Downloads/MP_data/MP_codes/MP/Data/sudden_drift/BPIC17_new.csv')
