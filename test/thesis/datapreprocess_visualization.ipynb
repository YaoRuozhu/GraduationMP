# %%
import pandas as pd
import numpy as np

# %%
file = '/Users/meruozhu/Downloads/MP_data/MP_codes/MP/Data/synthetic_dataset/IOR5000.csv'
data = pd.read_csv(file, low_memory=False)

# %%
data.iloc[[5,100,201,245],:]
# Out:
#        case                      event                startTime  \
# 5    b1_113         Assess eligibility  2004/02/11 19:30:07.055
# 100   b1_51           Assess loan risk  2004/02/05 19:43:08.092
# 201  b1_388       Check credit history  2004/03/05 20:34:00.185
# 245  b1_366  Send home insurance quote  2004/03/04 23:45:28.894
#
#                 completeTime            LogType  org:resource
# 5    2004/02/11 19:30:07.055  MXML.EnactmentLog           NaN
# 100  2004/02/05 19:43:08.092  MXML.EnactmentLog           NaN
# 201  2004/03/05 20:34:00.185  MXML.EnactmentLog           NaN
# 245  2004/03/04 23:45:28.894  MXML.EnactmentLog           NaN

# %%
data = data.iloc[:6, :]

# %%
data
# Out:
#      case                                  event                startTime  \
# 0  b1_113             Loan  application received  2004/02/11 17:30:00.000
# 1  b1_113  Check  application  form completeness  2004/02/11 17:55:28.917
# 2  b1_113                      Appraise property  2004/02/11 17:58:18.693
# 3  b1_113                   Check credit history  2004/02/11 18:12:06.935
# 4  b1_113                       Assess loan risk  2004/02/11 19:22:58.531
# 5  b1_113                     Assess eligibility  2004/02/11 19:30:07.055
#
#               completeTime            LogType  org:resource
# 0  2004/02/11 17:30:00.000  MXML.EnactmentLog           NaN
# 1  2004/02/11 17:55:28.917  MXML.EnactmentLog           NaN
# 2  2004/02/11 17:58:18.693  MXML.EnactmentLog           NaN
# 3  2004/02/11 18:12:06.935  MXML.EnactmentLog           NaN
# 4  2004/02/11 19:22:58.531  MXML.EnactmentLog           NaN
# 5  2004/02/11 19:30:07.055  MXML.EnactmentLog           NaN
